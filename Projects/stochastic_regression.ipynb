# %%
import numpy as np

# %%
m = 10000
n = 10000
k = 100

A = np.random.rand(k, k) # distributed over [0, 1) 
np.linalg.svd(A)
# Out:
# (array([[-0.08981945, -0.05725431,  0.16014372, ...,  0.06096503,
#           0.02917004, -0.14894394],
#         [-0.09260015, -0.22409515, -0.0007113 , ..., -0.00326257,
#          -0.13797596, -0.15286945],
#         [-0.1040529 , -0.03788227,  0.07138478, ..., -0.26015603,
#           0.09306403,  0.00408303],
#         ...,
#         [-0.105384  ,  0.03675752, -0.022988  , ..., -0.1495674 ,
#           0.05522907,  0.1915724 ],
#         [-0.09988167,  0.15102629,  0.02439909, ..., -0.02041972,
#           0.01563465, -0.09102145],
#         [-0.11017207,  0.01594744,  0.02828074, ...,  0.04530664,
#          -0.09372105, -0.05003399]]),
#  array([5.05391673e+01, 5.58409555e+00, 5.35076261e+00, 5.19334144e+00,
#         5.16162252e+00, 5.05431633e+00, 4.95434923e+00, 4.89627697e+00,
#         4.86555474e+00, 4.74777356e+00, 4.66821347e+00, 4.62808065e+00,
#         4.52072239e+00, 4.49303753e+00, 4.40802666e+00, 4.38913099e+00,
# ...
